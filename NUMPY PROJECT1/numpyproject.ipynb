# %%
import numpy as np  # array
from PIL import Image  #pic

import matplotlib.pyplot as plt

# %%
img =Image.open("image2.jpg")
img=np.array(img)
img[:,:,0]=np.clip(img[:,:,0]+15,200,40)
plt.imshow(img)
plt.axis("off")
plt.show()
